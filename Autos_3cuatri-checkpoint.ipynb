# %% [markdown]
# <img SRC="cr.jpg"/>

# %% [markdown]
# <center><h1 Style="color:#A52A2A"> Analisis de datos</h1></center>
# <center><h5> Universidad Castro Carazo</h5></center>
# <center><h6> 3C - 2022</h6></center>
#
# <p Style = "text-align: justify"> El tercer factor es el pago de pérdida promedio relativo por año de vehículo asegurado.
#
# Este valor está normalizado para todos los autos dentro de una clasificación de tamaño particular (pequeño de dos puertas, familiar, deportivo/especial, etc.), y representa la pérdida promedio por auto por año.
#
# Nota: Varios de los atributos de la base de datos podrían utilizarse como un atributo de "clase".</p>
#                                                        </br>
#
# <a href="https://archive.ics.uci.edu/ml/datasets/Automobile"> fuente de datos para el prceso de analisis

# %% [markdown]
# <h2 Style="color:#ff3300">1. Carga y estandarizacion de los set de datos</h2>

# %% [markdown]
# <p>Que se hace en esta etapa?</p>
#
# <ol>
#     <li>Importar las librerias de necesarias</li>
#     <li>Importar el o los set de datos</li>
#     <li>Revisar los ecabezados de los DataFrames</li>
#     <li>Si solo Si temenos mas de 1 set de datos - Unir los set de datos en un unico Dataframe</li>
# </ol>

# %% [markdown]
# <h3 Style="color:#ccff33">1.1 Importar las librerias</h3>

# %%
import pandas as pd #se usa para el manejo de los DateFram
import numpy as np #se usa para manejo de las estructuras de datos(array, listas, tuplas, diccionarios)
import matplotlib.pyplot as plt

# %% [markdown]
# <h3 Style="color:#7FFF00"> 1.2 Importar los Set de Datos</h3>

# %%
cols = ["symboling", "normalized", "make", "fuel", "aspiration", "doors",
       "style", "wheels", "engine", "base", "length", "width", "heingt",
       "curb", "engineType", "Cylinders", "engine-size", "system", "bore", "stroke",
       "compression", "horsepower", "peak", "City", "Higway", "price"]

df_1er_autos=pd.read_csv("Autos 1.csv", names=cols)
df_2do_autos=pd.read_csv("autos.csv", names=cols)

# %%
df_1er_autos.shape
# Out:
# (29, 26)

# %%
df_2do_autos.shape
# Out:
# (197, 26)

# %%
df_1er_autos.head(5)
# Out:
#    symboling normalized    make fuel aspiration doors        style wheels  \
# 0          2        134  toyota  gas        std   two      hardtop    rwd
# 1          2        134  toyota  gas        std   two    hatchback    rwd
# 2          2        134  toyota  gas        std   two      hardtop    rwd
# 3          2        134  toyota  gas        std   two    hatchback    rwd
# 4          2        134  toyota  gas        std   two  convertible    rwd
#
#   engine  base  ...  engine-size  system  bore  stroke compression horsepower  \
# 0  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
# 1  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
# 2  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
# 3  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
# 4  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
#
#    peak City  Higway  price
# 0  4800   24      30   9639
# 1  4800   24      30   9989
# 2  4800   24      30  11199
# 3  4800   24      30  11549
# 4  4800   24      30  17669
#
# [5 rows x 26 columns]

# %%
df_1er_autos.tail(5)
# Out:
#     symboling normalized        make    fuel aspiration doors  style wheels  \
# 24          0          ?  volkswagen  diesel      turbo  four  sedan    fwd
# 25          0          ?  volkswagen     gas        std  four  wagon    fwd
# 26         -2        103       volvo     gas        std  four  sedan    rwd
# 27         -1         74       volvo     gas        std  four  wagon    rwd
# 28         -2        103       volvo     gas        std  four  sedan    rwd
#
#    engine   base  ...  engine-size  system  bore  stroke compression  \
# 24  front  100.4  ...           97     idi  3.01    3.40        23.0
# 25  front  100.4  ...          109    mpfi  3.19    3.40         9.0
# 26  front  104.3  ...          141    mpfi  3.78    3.15         9.5
# 27  front  104.3  ...          141    mpfi  3.78    3.15         9.5
# 28  front  104.3  ...          141    mpfi  3.78    3.15         9.5
#
#    horsepower  peak City  Higway  price
# 24         68  4500   33      38  13845
# 25         88  5500   25      31  12290
# 26        114  5400   23      28  12940
# 27        114  5400   23      28  13415
# 28        114  5400   24      28  15985
#
# [5 rows x 26 columns]

# %%
df_1er_autos.describe()
# Out:
#        symboling        base      length      width     heingt         curb  \
# count  29.000000   29.000000   29.000000  29.000000  29.000000    29.000000
# mean    0.827586  100.103448  177.186207  66.134483  54.406897  2580.000000
# std     1.691765    3.082726    7.178327   0.917012   1.666676   310.887325
# min    -2.000000   94.500000  159.300000  64.000000  51.400000  2209.000000
# 25%    -1.000000   97.300000  171.700000  65.500000  53.000000  2300.000000
# 50%     2.000000  100.400000  176.200000  66.500000  54.900000  2536.000000
# 75%     2.000000  102.400000  183.100000  66.900000  55.700000  2912.000000
# max     3.000000  104.500000  188.800000  67.700000  57.500000  3151.000000
#
#        engine-size       bore     stroke  compression  horsepower  \
# count    29.000000  29.000000  29.000000    29.000000   29.000000
# mean    128.000000   3.330690   3.402069    11.475862  102.413793
# std      23.653752   0.240088   0.108278     5.318610   29.382353
# min      97.000000   3.010000   3.150000     8.500000   52.000000
# 25%     109.000000   3.190000   3.350000     9.000000   85.000000
# 50%     122.000000   3.270000   3.400000     9.300000   92.000000
# 75%     146.000000   3.620000   3.500000     9.500000  116.000000
# max     171.000000   3.780000   3.540000    23.000000  161.000000
#
#               peak       City     Higway         price
# count    29.000000  29.000000  29.000000     29.000000
# mean   4970.689655  25.896552  31.448276  11692.793103
# std     448.910833   5.045117   5.803855   2906.059106
# min    4200.000000  19.000000  24.000000   7775.000000
# 25%    4800.000000  24.000000  28.000000   9639.000000
# 50%    5200.000000  24.000000  30.000000  11199.000000
# 75%    5400.000000  27.000000  34.000000  13415.000000
# max    5500.000000  37.000000  46.000000  17669.000000

# %%
df_2do_autos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3          ?  alfa-romero  gas        std   two  convertible
# 1          3          ?  alfa-romero  gas        std   two  convertible
# 2          1          ?  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...          109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...          136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# 1        111  5000   21     27  16500
# 2        154  5000   19     26  16500
# 3        102  5500   24     30  13950
# 4        115  5500   18     22  17450
#
# [5 rows x 26 columns]

# %%
df_2do_autos.tail(5)
# Out:
#      symboling normalized        make    fuel aspiration doors  style wheels  \
# 192          0          ?  volkswagen  diesel      turbo  four  sedan    fwd
# 193          0          ?  volkswagen     gas        std  four  wagon    fwd
# 194         -2        103       volvo     gas        std  four  sedan    rwd
# 195         -1         74       volvo     gas        std  four  wagon    rwd
# 196         -2        103       volvo     gas        std  four  sedan    rwd
#
#     engine   base  ...  engine-size  system  bore  stroke compression  \
# 192  front  100.4  ...           97     idi  3.01    3.40        23.0
# 193  front  100.4  ...          109    mpfi  3.19    3.40         9.0
# 194  front  104.3  ...          141    mpfi  3.78    3.15         9.5
# 195  front  104.3  ...          141    mpfi  3.78    3.15         9.5
# 196  front  104.3  ...          141    mpfi  3.78    3.15         9.5
#
#     horsepower  peak City Higway  price
# 192         68  4500   33     38  13845
# 193         88  5500   25     31  12290
# 194        114  5400   23     28  12940
# 195        114  5400   23     28  13415
# 196        114  5400   24     28  15985
#
# [5 rows x 26 columns]

# %%
df_2do_autos.describe()
# Out:
#         symboling        base      length       width      heingt  \
# count  197.000000  197.000000  197.000000  197.000000  197.000000
# mean     0.913706   98.409645  173.450254   65.812690   53.628934
# std      1.202746    5.866965   12.213912    2.128306    2.438891
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.000000   52.000000
# 50%      1.000000   96.500000  172.600000   65.400000   53.900000
# 75%      2.000000  100.400000  178.500000   66.500000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#               curb  engine-size  compression        City      Higway
# count   197.000000   197.000000   197.000000  197.000000  197.000000
# mean   2534.796954   126.263959    10.128020   25.416244   30.984772
# std     520.401159    42.282594     3.934467    6.566717    6.908644
# min    1488.000000    61.000000     7.000000   13.000000   16.000000
# 25%    2140.000000    97.000000     8.600000   19.000000   25.000000
# 50%    2405.000000   110.000000     9.000000   25.000000   30.000000
# 75%    2844.000000   141.000000     9.400000   30.000000   36.000000
# max    4066.000000   326.000000    23.000000   49.000000   54.000000

# %% [markdown]
# <h5> Universidad Castro Carazo</h5>

# %% [markdown]
# <h1 Style="color:#A52A2A">1.3Revisar los encabezados de los DataFrame</h1></center>
# <p>Se motiva la estandarizacion de los nombres de las columnas, considerando lo siguiente</p>
# <ol>
#     <li>Los nombres de las columnas no deben contener espacios en blanco</li>
#     <li>Los nombres no deben empezar con numeros</li>
#     <li>Si el nombre se conforma de 2 o mas palabras la letra inicial de cada palabra va en mayuscula</li>
#     <li>No deben exitir nombres repetidos</li>

# %%
df_1er_autos.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylinders', 'engine-size', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'City', 'Higway',
#        'price'],
#       dtype='object')

# %%
df_2do_autos.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylinders', 'engine-size', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'City', 'Higway',
#        'price'],
#       dtype='object')

# %%
df_1er_autos.rename({"engine-size":"engineSize"}, axis=1, inplace=True)
df_2do_autos.rename({"engine-size":"engineSize"}, axis=1, inplace=True)
df_1er_autos.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylinders', 'engineSize', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'City', 'Higway',
#        'price'],
#       dtype='object')

# %%
df_2do_autos.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylinders', 'engineSize', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'City', 'Higway',
#        'price'],
#       dtype='object')

# %% [markdown]
# <h5 Style="color: #778899"> Revision de variables </h5>
# <p> Este proceso de revision permite identificar variables o datos que deben ser analizados de manera independiente, porque no concuerdan con la metadata </p>

# %%
df_1er_autos.describe()
# Out:
#        symboling        base      length      width     heingt         curb  \
# count  29.000000   29.000000   29.000000  29.000000  29.000000    29.000000
# mean    0.827586  100.103448  177.186207  66.134483  54.406897  2580.000000
# std     1.691765    3.082726    7.178327   0.917012   1.666676   310.887325
# min    -2.000000   94.500000  159.300000  64.000000  51.400000  2209.000000
# 25%    -1.000000   97.300000  171.700000  65.500000  53.000000  2300.000000
# 50%     2.000000  100.400000  176.200000  66.500000  54.900000  2536.000000
# 75%     2.000000  102.400000  183.100000  66.900000  55.700000  2912.000000
# max     3.000000  104.500000  188.800000  67.700000  57.500000  3151.000000
#
#        engineSize       bore     stroke  compression  horsepower         peak  \
# count   29.000000  29.000000  29.000000    29.000000   29.000000    29.000000
# mean   128.000000   3.330690   3.402069    11.475862  102.413793  4970.689655
# std     23.653752   0.240088   0.108278     5.318610   29.382353   448.910833
# min     97.000000   3.010000   3.150000     8.500000   52.000000  4200.000000
# 25%    109.000000   3.190000   3.350000     9.000000   85.000000  4800.000000
# 50%    122.000000   3.270000   3.400000     9.300000   92.000000  5200.000000
# 75%    146.000000   3.620000   3.500000     9.500000  116.000000  5400.000000
# max    171.000000   3.780000   3.540000    23.000000  161.000000  5500.000000
#
#             City     Higway         price
# count  29.000000  29.000000     29.000000
# mean   25.896552  31.448276  11692.793103
# std     5.045117   5.803855   2906.059106
# min    19.000000  24.000000   7775.000000
# 25%    24.000000  28.000000   9639.000000
# 50%    24.000000  30.000000  11199.000000
# 75%    27.000000  34.000000  13415.000000
# max    37.000000  46.000000  17669.000000

# %%
df_1er_autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symboling    29 non-null     int64
#  1   normalized   29 non-null     object
#  2   make         29 non-null     object
#  3   fuel         29 non-null     object
#  4   aspiration   29 non-null     object
#  5   doors        29 non-null     object
#  6   style        29 non-null     object
#  7   wheels       29 non-null     object
#  8   engine       29 non-null     object
#  9   base         29 non-null     float64
#  10  length       29 non-null     float64
#  11  width        29 non-null     float64
#  12  heingt       29 non-null     float64
#  13  curb         29 non-null     int64
#  14  engineType   29 non-null     object
#  15  Cylinders    29 non-null     object
#  16  engineSize   29 non-null     int64
#  17  system       29 non-null     object
#  18  bore         29 non-null     float64
#  19  stroke       29 non-null     float64
#  20  compression  29 non-null     float64
#  21  horsepower   29 non-null     int64
#  22  peak         29 non-null     int64
#  23  City         29 non-null     int64
#  24  Higway       29 non-null     int64
#  25  price        29 non-null     int64
# dtypes: float64(7), int64(8), object(11)
# memory usage: 6.0+ KB

# %%
df_1er_autos.head(5)
# Out:
#    symboling normalized    make fuel aspiration doors        style wheels  \
# 0          2        134  toyota  gas        std   two      hardtop    rwd
# 1          2        134  toyota  gas        std   two    hatchback    rwd
# 2          2        134  toyota  gas        std   two      hardtop    rwd
# 3          2        134  toyota  gas        std   two    hatchback    rwd
# 4          2        134  toyota  gas        std   two  convertible    rwd
#
#   engine  base  ...  engineSize  system  bore  stroke compression horsepower  \
# 0  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
# 1  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
# 2  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
# 3  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
# 4  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
#
#    peak City  Higway  price
# 0  4800   24      30   9639
# 1  4800   24      30   9989
# 2  4800   24      30  11199
# 3  4800   24      30  11549
# 4  4800   24      30  17669
#
# [5 rows x 26 columns]

# %%
df_2do_autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symboling    197 non-null    int64
#  1   normalized   197 non-null    object
#  2   make         197 non-null    object
#  3   fuel         197 non-null    object
#  4   aspiration   197 non-null    object
#  5   doors        197 non-null    object
#  6   style        197 non-null    object
#  7   wheels       197 non-null    object
#  8   engine       197 non-null    object
#  9   base         197 non-null    float64
#  10  length       197 non-null    float64
#  11  width        197 non-null    float64
#  12  heingt       197 non-null    float64
#  13  curb         197 non-null    int64
#  14  engineType   197 non-null    object
#  15  Cylinders    197 non-null    object
#  16  engineSize   197 non-null    int64
#  17  system       197 non-null    object
#  18  bore         197 non-null    object
#  19  stroke       197 non-null    object
#  20  compression  197 non-null    float64
#  21  horsepower   197 non-null    object
#  22  peak         197 non-null    object
#  23  City         197 non-null    int64
#  24  Higway       197 non-null    int64
#  25  price        197 non-null    object
# dtypes: float64(5), int64(5), object(16)
# memory usage: 40.1+ KB

# %%
temp = df_1er_autos.groupby(["style"]).count()
print(temp)
# Out:
#              symboling  normalized  make  fuel  aspiration  doors  wheels  \
# style
# convertible          2           2     2     2           2      2       2
# hardtop              2           2     2     2           2      2       2
# hatchback            7           7     7     7           7      7       7
# sedan               15          15    15    15          15     15      15
# wagon                3           3     3     3           3      3       3
#
#              engine  base  length  ...  engineSize  system  bore  stroke  \
# style                              ...
# convertible       2     2       2  ...           2       2     2       2
# hardtop           2     2       2  ...           2       2     2       2
# hatchback         7     7       7  ...           7       7     7       7
# sedan            15    15      15  ...          15      15    15      15
# wagon             3     3       3  ...           3       3     3       3
#
#              compression  horsepower  peak  City  Higway  price
# style
# convertible            2           2     2     2       2      2
# hardtop                2           2     2     2       2      2
# hatchback              7           7     7     7       7      7
# sedan                 15          15    15    15      15     15
# wagon                  3           3     3     3       3      3
#
# [5 rows x 25 columns]

# %%
temp = df_1er_autos.groupby(["style"]).count()
temp = temp.iloc[:,:1]
temp
# Out:
#              symboling
# style
# convertible          2
# hardtop              2
# hatchback            7
# sedan               15
# wagon                3

# %% [markdown]
# <h3>1.4 Unir set de datos</h3>

# %%
unionArchivos = [df_1er_autos, df_2do_autos]
dfAutos = pd.concat(unionArchivos)
dfAutos.shape
# Out:
# (226, 26)

# %%
dfAutos.head(5)
# Out:
#    symboling normalized    make fuel aspiration doors        style wheels  \
# 0          2        134  toyota  gas        std   two      hardtop    rwd
# 1          2        134  toyota  gas        std   two    hatchback    rwd
# 2          2        134  toyota  gas        std   two      hardtop    rwd
# 3          2        134  toyota  gas        std   two    hatchback    rwd
# 4          2        134  toyota  gas        std   two  convertible    rwd
#
#   engine  base  ...  engineSize  system  bore  stroke compression horsepower  \
# 0  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
# 1  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
# 2  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
# 3  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
# 4  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
#
#    peak City Higway  price
# 0  4800   24     30   9639
# 1  4800   24     30   9989
# 2  4800   24     30  11199
# 3  4800   24     30  11549
# 4  4800   24     30  17669
#
# [5 rows x 26 columns]

# %% [markdown]
# <h2 style='color:#4b0088'>2.Manejo de los valores faltantes o perdidos<h2/>
# <p>Que se hace en este apartado?</p>
# <ol>
#     <li>Identificar como se muestran los valores faltantes y los estandarizamos(NaN)</li>
#     <li>Contar la cantidad de valores faltantes por variables</li>
#     <li>Analisis de imputacion de valores numeros con la media</li>
#     <li>Analisis de imputacion de valores categoricos con el mas frecuente</li>
#     <li>Eliminar filas con valores faltantes</li>
# </ol>
#
# <h2 style='color:#800088'>2.1 Identificar como se muestran los valores faltantes y los estandarizamos (NaN)</h2>

# %%
dfAutos
# Out:
#      symboling normalized        make    fuel aspiration doors        style  \
# 0            2        134      toyota     gas        std   two      hardtop
# 1            2        134      toyota     gas        std   two    hatchback
# 2            2        134      toyota     gas        std   two      hardtop
# 3            2        134      toyota     gas        std   two    hatchback
# 4            2        134      toyota     gas        std   two  convertible
# ..         ...        ...         ...     ...        ...   ...          ...
# 192          0          ?  volkswagen  diesel      turbo  four        sedan
# 193          0          ?  volkswagen     gas        std  four        wagon
# 194         -2        103       volvo     gas        std  four        sedan
# 195         -1         74       volvo     gas        std  four        wagon
# 196         -2        103       volvo     gas        std  four        sedan
#
#     wheels engine   base  ...  engineSize  system  bore  stroke compression  \
# 0      rwd  front   98.4  ...         146    mpfi  3.62     3.5         9.3
# 1      rwd  front   98.4  ...         146    mpfi  3.62     3.5         9.3
# 2      rwd  front   98.4  ...         146    mpfi  3.62     3.5         9.3
# 3      rwd  front   98.4  ...         146    mpfi  3.62     3.5         9.3
# 4      rwd  front   98.4  ...         146    mpfi  3.62     3.5         9.3
# ..     ...    ...    ...  ...         ...     ...   ...     ...         ...
# 192    fwd  front  100.4  ...          97     idi  3.01    3.40        23.0
# 193    fwd  front  100.4  ...         109    mpfi  3.19    3.40         9.0
# 194    rwd  front  104.3  ...         141    mpfi  3.78    3.15         9.5
# 195    rwd  front  104.3  ...         141    mpfi  3.78    3.15         9.5
# 196    rwd  front  104.3  ...         141    mpfi  3.78    3.15         9.5
#
#     horsepower  peak City Higway  price
# 0          116  4800   24     30   9639
# 1          116  4800   24     30   9989
# 2          116  4800   24     30  11199
# 3          116  4800   24     30  11549
# 4          116  4800   24     30  17669
# ..         ...   ...  ...    ...    ...
# 192         68  4500   33     38  13845
# 193         88  5500   25     31  12290
# 194        114  5400   23     28  12940
# 195        114  5400   23     28  13415
# 196        114  5400   24     28  15985
#
# [226 rows x 26 columns]

# %%
dfAutos.replace('?',np.nan,inplace = True)
dfAutos.head(10)
# Out:
#    symboling normalized    make    fuel aspiration doors        style wheels  \
# 0          2        134  toyota     gas        std   two      hardtop    rwd
# 1          2        134  toyota     gas        std   two    hatchback    rwd
# 2          2        134  toyota     gas        std   two      hardtop    rwd
# 3          2        134  toyota     gas        std   two    hatchback    rwd
# 4          2        134  toyota     gas        std   two  convertible    rwd
# 5         -1         65  toyota     gas        std  four        sedan    fwd
# 6         -1         65  toyota  diesel      turbo  four        sedan    fwd
# 7         -1         65  toyota     gas        std  four    hatchback    fwd
# 8         -1         65  toyota     gas        std  four        sedan    fwd
# 9         -1         65  toyota     gas        std  four    hatchback    fwd
#
#   engine   base  ...  engineSize  system  bore  stroke compression horsepower  \
# 0  front   98.4  ...         146    mpfi  3.62     3.5         9.3        116
# 1  front   98.4  ...         146    mpfi  3.62     3.5         9.3        116
# 2  front   98.4  ...         146    mpfi  3.62     3.5         9.3        116
# 3  front   98.4  ...         146    mpfi  3.62     3.5         9.3        116
# 4  front   98.4  ...         146    mpfi  3.62     3.5         9.3        116
# 5  front  102.4  ...         122    mpfi  3.31    3.54         8.7         92
# 6  front  102.4  ...         110     idi  3.27    3.35        22.5         73
# 7  front  102.4  ...         122    mpfi  3.31    3.54         8.7         92
# 8  front  102.4  ...         122    mpfi  3.31    3.54         8.7         92
# 9  front  102.4  ...         122    mpfi  3.31    3.54         8.7         92
#
#    peak City Higway  price
# 0  4800   24     30   9639
# 1  4800   24     30   9989
# 2  4800   24     30  11199
# 3  4800   24     30  11549
# 4  4800   24     30  17669
# 5  4200   29     34   8948
# 6  4500   30     33  10698
# 7  4200   27     32   9988
# 8  4200   27     32  10898
# 9  4200   27     32  11248
#
# [10 rows x 26 columns]

# %%
dfAutos.tail(10)
# Out:
#      symboling normalized        make    fuel aspiration doors        style  \
# 187          2         94  volkswagen  diesel      turbo  four        sedan
# 188          2         94  volkswagen     gas        std  four        sedan
# 189          3        NaN  volkswagen     gas        std   two  convertible
# 190          3        256  volkswagen     gas        std   two    hatchback
# 191          0        NaN  volkswagen     gas        std  four        sedan
# 192          0        NaN  volkswagen  diesel      turbo  four        sedan
# 193          0        NaN  volkswagen     gas        std  four        wagon
# 194         -2        103       volvo     gas        std  four        sedan
# 195         -1         74       volvo     gas        std  four        wagon
# 196         -2        103       volvo     gas        std  four        sedan
#
#     wheels engine   base  ...  engineSize  system  bore  stroke compression  \
# 187    fwd  front   97.3  ...          97     idi  3.01    3.40        23.0
# 188    fwd  front   97.3  ...         109    mpfi  3.19    3.40        10.0
# 189    fwd  front   94.5  ...         109    mpfi  3.19    3.40         8.5
# 190    fwd  front   94.5  ...         109    mpfi  3.19    3.40         8.5
# 191    fwd  front  100.4  ...         136    mpfi  3.19    3.40         8.5
# 192    fwd  front  100.4  ...          97     idi  3.01    3.40        23.0
# 193    fwd  front  100.4  ...         109    mpfi  3.19    3.40         9.0
# 194    rwd  front  104.3  ...         141    mpfi  3.78    3.15         9.5
# 195    rwd  front  104.3  ...         141    mpfi  3.78    3.15         9.5
# 196    rwd  front  104.3  ...         141    mpfi  3.78    3.15         9.5
#
#     horsepower  peak City Higway  price
# 187         68  4500   37     42   9495
# 188        100  5500   26     32   9995
# 189         90  5500   24     29  11595
# 190         90  5500   24     29   9980
# 191        110  5500   19     24  13295
# 192         68  4500   33     38  13845
# 193         88  5500   25     31  12290
# 194        114  5400   23     28  12940
# 195        114  5400   23     28  13415
# 196        114  5400   24     28  15985
#
# [10 rows x 26 columns]

# %% [markdown]
# <h2 style='color:#800088'>2.2 Contar la cantidad de valores faltantes por variable</h2>

# %%
dfvaloresfaltantes = dfAutos.isnull()

# %%
dfvaloresfaltantes.head(10)
# Out:
#    symboling  normalized   make   fuel  aspiration  doors  style  wheels  \
# 0      False       False  False  False       False  False  False   False
# 1      False       False  False  False       False  False  False   False
# 2      False       False  False  False       False  False  False   False
# 3      False       False  False  False       False  False  False   False
# 4      False       False  False  False       False  False  False   False
# 5      False       False  False  False       False  False  False   False
# 6      False       False  False  False       False  False  False   False
# 7      False       False  False  False       False  False  False   False
# 8      False       False  False  False       False  False  False   False
# 9      False       False  False  False       False  False  False   False
#
#    engine   base  ...  engineSize  system   bore  stroke  compression  \
# 0   False  False  ...       False   False  False   False        False
# 1   False  False  ...       False   False  False   False        False
# 2   False  False  ...       False   False  False   False        False
# 3   False  False  ...       False   False  False   False        False
# 4   False  False  ...       False   False  False   False        False
# 5   False  False  ...       False   False  False   False        False
# 6   False  False  ...       False   False  False   False        False
# 7   False  False  ...       False   False  False   False        False
# 8   False  False  ...       False   False  False   False        False
# 9   False  False  ...       False   False  False   False        False
#
#    horsepower   peak   City  Higway  price
# 0       False  False  False   False  False
# 1       False  False  False   False  False
# 2       False  False  False   False  False
# 3       False  False  False   False  False
# 4       False  False  False   False  False
# 5       False  False  False   False  False
# 6       False  False  False   False  False
# 7       False  False  False   False  False
# 8       False  False  False   False  False
# 9       False  False  False   False  False
#
# [10 rows x 26 columns]

# %%
for column in dfvaloresfaltantes.columns.values.tolist():
    print(column)
    print(dfvaloresfaltantes[column].value_counts())
    print("")
# Out:
# symboling
# False    226
# Name: symboling, dtype: int64
#
# normalized
# False    180
# True      46
# Name: normalized, dtype: int64
#
# make
# False    226
# Name: make, dtype: int64
#
# fuel
# False    226
# Name: fuel, dtype: int64
#
# aspiration
# False    226
# Name: aspiration, dtype: int64
#
# doors
# False    224
# True       2
# Name: doors, dtype: int64
#
# style
# False    226
# Name: style, dtype: int64
#
# wheels
# False    226
# Name: wheels, dtype: int64
#
# engine
# False    226
# Name: engine, dtype: int64
#
# base
# False    226
# Name: base, dtype: int64
#
# length
# False    226
# Name: length, dtype: int64
#
# width
# False    226
# Name: width, dtype: int64
#
# heingt
# False    226
# Name: heingt, dtype: int64
#
# curb
# False    226
# Name: curb, dtype: int64
#
# engineType
# False    226
# Name: engineType, dtype: int64
#
# Cylinders
# False    226
# Name: Cylinders, dtype: int64
#
# engineSize
# False    226
# Name: engineSize, dtype: int64
#
# system
# False    226
# Name: system, dtype: int64
#
# bore
# False    222
# True       4
# Name: bore, dtype: int64
#
# stroke
# False    222
# True       4
# Name: stroke, dtype: int64
#
# compression
# False    226
# Name: compression, dtype: int64
#
# horsepower
# False    224
# True       2
# Name: horsepower, dtype: int64
#
# peak
# False    224
# True       2
# Name: peak, dtype: int64
#
# City
# False    226
# Name: City, dtype: int64
#
# Higway
# False    226
# Name: Higway, dtype: int64
#
# price
# False    222
# True       4
# Name: price, dtype: int64

# %%
dfAutos.describe()
# Out:
#         symboling        base      length       width      heingt  \
# count  226.000000  226.000000  226.000000  226.000000  226.000000
# mean     0.902655   98.626991  173.929646   65.853982   53.728761
# std      1.271672    5.611570   11.744470    2.015475    2.365420
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  167.300000   64.200000   52.000000
# 50%      1.000000   97.250000  173.200000   65.500000   54.100000
# 75%      2.000000  101.800000  180.200000   66.500000   55.600000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#               curb  engineSize  compression        City      Higway
# count   226.000000  226.000000   226.000000  226.000000  226.000000
# mean   2540.597345  126.486726    10.300973   25.477876   31.044248
# std     498.165891   40.340465     4.148393    6.384143    6.767096
# min    1488.000000   61.000000     7.000000   13.000000   16.000000
# 25%    2205.250000   98.000000     8.625000   20.000000   25.000000
# 50%    2414.000000  115.000000     9.000000   25.000000   30.000000
# 75%    2846.250000  146.000000     9.400000   30.000000   34.000000
# max    4066.000000  326.000000    23.000000   49.000000   54.000000

# %% [markdown]
# <h2 style='color:#800088'>2.3Analisis de imputacion de valores numeros con la media</h2>

# %% [markdown]
# <img SRC="Captura.JPG" alt ="VAlores Faltantes">

# %%
mean_value = dfAutos["peak"].astype("float").mean(axis=0) # Obteniendo la media de la variable
print("La media es: ", mean_value)
# Out:
# La media es:  5100.892857142857

# %%
dfAutos["peak"].replace(np.nan,5100, inplace = True)

# %%
mean_peak= dfAutos["normalized"].astype("float").mean(axis = 0)
print("La media de normalized es: ",mean_peak)
# Out:
# La media de normalized es:  122.28333333333333

# %%
dfAutos["normalized"].replace(np.nan, 122, inplace = True)

# %%
mean_peak= dfAutos["symboling"].astype("float").mean(axis = 0)
print("La media de normalized es: ",mean_peak)
# Out:
# La media de normalized es:  0.9099099099099099

# %%
dfAutos["symboling"].replace(np.nan, 0.90, inplace = True)

# %%
mean_peak= dfAutos["price"].astype("float").mean(axis = 0)
print("La media de normalized es: ",mean_peak)
# Out:
# La media de normalized es:  12780.941441441442

# %%
dfAutos["price"].replace(np.nan,  12780, inplace = True)

# %%
dfAutos['peak'].replace(np.nan, 5100, inplace = True)
dfAutos.head(5)
# Out:
#    symboling normalized    make fuel aspiration doors        style wheels  \
# 0          2        134  toyota  gas        std   two      hardtop    rwd
# 1          2        134  toyota  gas        std   two    hatchback    rwd
# 2          2        134  toyota  gas        std   two      hardtop    rwd
# 3          2        134  toyota  gas        std   two    hatchback    rwd
# 4          2        134  toyota  gas        std   two  convertible    rwd
#
#   engine  base  ...  engineSize  system  bore  stroke compression horsepower  \
# 0  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
# 1  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
# 2  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
# 3  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
# 4  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
#
#    peak City Higway  price
# 0  4800   24     30   9639
# 1  4800   24     30   9989
# 2  4800   24     30  11199
# 3  4800   24     30  11549
# 4  4800   24     30  17669
#
# [5 rows x 26 columns]

# %%
dfAutos["doors"].value_counts().idxmax()
# Out:
# 'four'

# %%
dfAutos["doors"].replace(np.nan,"four",inplace = True)
dfAutos.head(5)
# Out:
#    symboling normalized    make fuel aspiration doors        style wheels  \
# 0          2        134  toyota  gas        std   two      hardtop    rwd
# 1          2        134  toyota  gas        std   two    hatchback    rwd
# 2          2        134  toyota  gas        std   two      hardtop    rwd
# 3          2        134  toyota  gas        std   two    hatchback    rwd
# 4          2        134  toyota  gas        std   two  convertible    rwd
#
#   engine  base  ...  engineSize  system  bore  stroke compression horsepower  \
# 0  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
# 1  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
# 2  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
# 3  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
# 4  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
#
#    peak City Higway  price
# 0  4800   24     30   9639
# 1  4800   24     30   9989
# 2  4800   24     30  11199
# 3  4800   24     30  11549
# 4  4800   24     30  17669
#
# [5 rows x 26 columns]

# %% [markdown]
# <h2 style='color:#800088'>2.4 Analisis de imputacion de valores categoricos con el mas frecuente</h2>

# %%
dfAutos['doors'].value_counts().idxmax()
# Out:
# 'four'

# %%
dfAutos['doors'].replace(np.nan, 'four', inplace = True)
dfAutos.head(5)
# Out:
#    symboling normalized    make fuel aspiration doors        style wheels  \
# 0          2        134  toyota  gas        std   two      hardtop    rwd
# 1          2        134  toyota  gas        std   two    hatchback    rwd
# 2          2        134  toyota  gas        std   two      hardtop    rwd
# 3          2        134  toyota  gas        std   two    hatchback    rwd
# 4          2        134  toyota  gas        std   two  convertible    rwd
#
#   engine  base  ...  engineSize  system  bore  stroke compression horsepower  \
# 0  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
# 1  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
# 2  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
# 3  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
# 4  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
#
#    peak City Higway  price
# 0  4800   24     30   9639
# 1  4800   24     30   9989
# 2  4800   24     30  11199
# 3  4800   24     30  11549
# 4  4800   24     30  17669
#
# [5 rows x 26 columns]

# %% [markdown]
# <h2 style='color:#800088'> 2.5 Eliminar filas con valores faltantes</h2>

# %%
dfAutos.dropna(subset = ["price"], axis = 0, inplace = True)
dfAutos.reset_index(drop=True, inplace = True)

# %%
dfValoresFaltantes = dfAutos.isnull()
dfValoresFaltantes.head(5)
for column in dfValoresFaltantes.columns.values.tolist():
    print(column)
    print(dfValoresFaltantes[column].value_counts())
    print("")
# Out:
# symboling
# False    222
# Name: symboling, dtype: int64
#
# normalized
# False    222
# Name: normalized, dtype: int64
#
# make
# False    222
# Name: make, dtype: int64
#
# fuel
# False    222
# Name: fuel, dtype: int64
#
# aspiration
# False    222
# Name: aspiration, dtype: int64
#
# doors
# False    222
# Name: doors, dtype: int64
#
# style
# False    222
# Name: style, dtype: int64
#
# wheels
# False    222
# Name: wheels, dtype: int64
#
# engine
# False    222
# Name: engine, dtype: int64
#
# base
# False    222
# Name: base, dtype: int64
#
# length
# False    222
# Name: length, dtype: int64
#
# width
# False    222
# Name: width, dtype: int64
#
# heingt
# False    222
# Name: heingt, dtype: int64
#
# curb
# False    222
# Name: curb, dtype: int64
#
# engineType
# False    222
# Name: engineType, dtype: int64
#
# Cylinders
# False    222
# Name: Cylinders, dtype: int64
#
# engineSize
# False    222
# Name: engineSize, dtype: int64
#
# system
# False    222
# Name: system, dtype: int64
#
# bore
# False    218
# True       4
# Name: bore, dtype: int64
#
# stroke
# False    218
# True       4
# Name: stroke, dtype: int64
#
# compression
# False    222
# Name: compression, dtype: int64
#
# horsepower
# False    220
# True       2
# Name: horsepower, dtype: int64
#
# peak
# False    222
# Name: peak, dtype: int64
#
# City
# False    222
# Name: City, dtype: int64
#
# Higway
# False    222
# Name: Higway, dtype: int64
#
# price
# False    222
# Name: price, dtype: int64

# %% [markdown]
# <h2 style='color:#006400'>3 Estandarizacion de los datos</h2>

# %% [markdown]
# <p> Que se hace en este apartado? </p>
#
#
#
# <ol>
#     <li>Se verifica el dominio de la variable y se ajusta, si es necesario</li>
#     <li>Se convierten los valores en función de su interpretación </li>
#     <li>Se normalizan los datos para que los valores distintos queden entre 0 y 1</li>
#     <li>Binning</li>
# </ol>
#
#
#
# <h3 style="color: #B22222">3.1 Verificacion del dominio de variables</h3>

# %%
dfAutos.head(5)
# Out:
#    symboling  normalized    make fuel aspiration doors        style wheels  \
# 0          2         134  toyota  gas        std   two      hardtop    rwd
# 1          2         134  toyota  gas        std   two    hatchback    rwd
# 2          2         134  toyota  gas        std   two      hardtop    rwd
# 3          2         134  toyota  gas        std   two    hatchback    rwd
# 4          2         134  toyota  gas        std   two  convertible    rwd
#
#   engine  base  ...  engineSize  system  bore  stroke compression horsepower  \
# 0  front  98.4  ...         146    mpfi  3.62     3.5         9.3      116.0
# 1  front  98.4  ...         146    mpfi  3.62     3.5         9.3      116.0
# 2  front  98.4  ...         146    mpfi  3.62     3.5         9.3      116.0
# 3  front  98.4  ...         146    mpfi  3.62     3.5         9.3      116.0
# 4  front  98.4  ...         146    mpfi  3.62     3.5         9.3      116.0
#
#      peak City  Higway    price
# 0  4800.0   24      30   9639.0
# 1  4800.0   24      30   9989.0
# 2  4800.0   24      30  11199.0
# 3  4800.0   24      30  11549.0
# 4  4800.0   24      30  17669.0
#
# [5 rows x 26 columns]

# %%
dfAutos.dtypes
# Out:
# symboling        int64
# normalized      object
# make            object
# fuel            object
# aspiration      object
# doors           object
# style           object
# wheels          object
# engine          object
# base           float64
# length         float64
# width          float64
# heingt         float64
# curb             int64
# engineType      object
# Cylinders       object
# engineSize       int64
# system          object
# bore            object
# stroke          object
# compression    float64
# horsepower      object
# peak            object
# City             int64
# Higway           int64
# price           object
# dtype: object

# %%
dfAutos[['normalized']] = dfAutos[['normalized']].astype("int")
dfAutos[['bore', 'stroke', 'peak', 'horsepower','price']] = dfAutos[['bore', 'stroke', 'peak', 'horsepower', 'price']].astype("float")

# %%
dfAutos[['normalized']] = dfAutos[['normalized']].astype("int")

# %%
dfAutos[['bore','stroke','peak','horsepower','price']] = dfAutos[['bore','stroke','peak','horsepower','price']].astype("float")

# %%
dfAutos.dtypes
# Out:
# symboling        int64
# normalized       int32
# make            object
# fuel            object
# aspiration      object
# doors           object
# style           object
# wheels          object
# engine          object
# base           float64
# length         float64
# width          float64
# heingt         float64
# curb             int64
# engineType      object
# Cylinders       object
# engineSize       int64
# system          object
# bore           float64
# stroke         float64
# compression    float64
# horsepower     float64
# peak           float64
# City             int64
# Higway           int64
# price          float64
# dtype: object

# %% [markdown]
# <h3 style="color: #006400">3.2 Estandarizacion de valores</h3>

# %%
dfAutos.head(3)
# Out:
#    symboling  normalized    make fuel aspiration doors      style wheels  \
# 0          2         134  toyota  gas        std   two    hardtop    rwd
# 1          2         134  toyota  gas        std   two  hatchback    rwd
# 2          2         134  toyota  gas        std   two    hardtop    rwd
#
#   engine  base  ...  engineSize  system  bore  stroke compression horsepower  \
# 0  front  98.4  ...         146    mpfi  3.62     3.5         9.3      116.0
# 1  front  98.4  ...         146    mpfi  3.62     3.5         9.3      116.0
# 2  front  98.4  ...         146    mpfi  3.62     3.5         9.3      116.0
#
#      peak City  Higway    price
# 0  4800.0   24      30   9639.0
# 1  4800.0   24      30   9989.0
# 2  4800.0   24      30  11199.0
#
# [3 rows x 26 columns]

# %%
dfAutos["City L/100km"] = 235/dfAutos["City"]
dfAutos["Higway L/100km"] = 235/dfAutos["Higway"]
dfAutos.head(3)
# Out:
#    symboling  normalized    make fuel aspiration doors      style wheels  \
# 0          2         134  toyota  gas        std   two    hardtop    rwd
# 1          2         134  toyota  gas        std   two  hatchback    rwd
# 2          2         134  toyota  gas        std   two    hardtop    rwd
#
#   engine  base  ...  bore  stroke  compression  horsepower    peak City  \
# 0  front  98.4  ...  3.62     3.5          9.3       116.0  4800.0   24
# 1  front  98.4  ...  3.62     3.5          9.3       116.0  4800.0   24
# 2  front  98.4  ...  3.62     3.5          9.3       116.0  4800.0   24
#
#    Higway    price  City L/100km  Higway L/100km
# 0      30   9639.0      9.791667        7.833333
# 1      30   9989.0      9.791667        7.833333
# 2      30  11199.0      9.791667        7.833333
#
# [3 rows x 28 columns]

# %% [markdown]
# <h2 style='color:#006400'>3.3 Normalizacion de Valores</h2>

# %%
dftemp = dfAutos[["length","width","heingt"]]
dftemp.head(5)
# Out:
#    length  width  heingt
# 0   176.2   65.6    52.0
# 1   176.2   65.6    52.0
# 2   176.2   65.6    52.0
# 3   176.2   65.6    52.0
# 4   176.2   65.6    53.0

# %%
dfAutos["length"] = dfAutos["length"]/dfAutos["length"].max()
dfAutos["width"] = dfAutos["width"]/dfAutos["width"].max()
dfAutos["heingt"] = dfAutos["heingt"]/dfAutos["heingt"].max()

# %%
dftemp2 = dfAutos [["length", "width", "heingt" ]]

# %%
dftemp2.head(10)
# Out:
#      length     width    heingt
# 0  0.846708  0.911111  0.869565
# 1  0.846708  0.911111  0.869565
# 2  0.846708  0.911111  0.869565
# 3  0.846708  0.911111  0.869565
# 4  0.846708  0.911111  0.886288
# 5  0.843825  0.923611  0.918060
# 6  0.843825  0.923611  0.918060
# 7  0.843825  0.923611  0.901338
# 8  0.843825  0.923611  0.918060
# 9  0.843825  0.923611  0.901338

# %% [markdown]
# <h2 style='color:#006400'>3.4 Binning</h2>

# %%
dftemp = dfAutos["horsepower"]
dftemp.head(10)
# Out:
# 0    116.0
# 1    116.0
# 2    116.0
# 3    116.0
# 4    116.0
# 5     92.0
# 6     73.0
# 7     92.0
# 8     92.0
# 9     92.0
# Name: horsepower, dtype: float64

# %%
dfAutos.dtypes
# Out:
# symboling           int64
# normalized          int32
# make               object
# fuel               object
# aspiration         object
# doors              object
# style              object
# wheels             object
# engine             object
# base              float64
# length            float64
# width             float64
# heingt            float64
# curb                int64
# engineType         object
# Cylinders          object
# engineSize          int64
# system             object
# bore              float64
# stroke            float64
# compression       float64
# horsepower        float64
# peak              float64
# City                int64
# Higway              int64
# price             float64
# City L/100km      float64
# Higway L/100km    float64
# dtype: object

# %%
bins = np.linspace(min(dfAutos["horsepower"]), max(dfAutos["horsepower"]), 4)
bins
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
groupNames = ["bajo", "medio", "alto"]
dfAutos["horsepowerBins"] = pd.cut(dfAutos["horsepower"], bins, labels = groupNames, include_lowest = True)
dfAutos[["horsepower", "horsepowerBins"]].head(5)
# Out:
#    horsepower horsepowerBins
# 0       116.0           bajo
# 1       116.0           bajo
# 2       116.0           bajo
# 3       116.0           bajo
# 4       116.0           bajo

# %%
dfAutos["horsepowerBins"].value_counts()
# Out:
# bajo     172
# medio     43
# alto       5
# Name: horsepowerBins, dtype: int64

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot



plt.pyplot.hist(dfAutos["horsepower"])

plt.pyplot.hist(dfAutos["horsepower"])
plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("cantidad")
plt.pyplot.title("horsepower")
# Out:
# Text(0.5, 1.0, 'horsepower')

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot

plt.pyplot.hist(dfAutos["horsepowerBins"])

plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("cantidad")
plt.pyplot.title("horsepower")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [84], in <cell line: 5>()
#       2 import matplotlib as plt
#       3 from matplotlib import pyplot
# ----> 5 plt.pyplot.hist(dfAutos["horsepowerBins"])
#       7 plt.pyplot.xlabel("horsepower")
#       8 plt.pyplot.ylabel("cantidad")
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2590, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2584 @_copy_docstring_and_deprecators(Axes.hist)
#    2585 def hist(
#    2586         x, bins=None, range=None, density=False, weights=None,
#    2587         cumulative=False, bottom=None, histtype='bar', align='mid',
#    2588         orientation='vertical', rwidth=None, log=False, color=None,
#    2589         label=None, stacked=False, *, data=None, **kwargs):
# -> 2590     return gca().hist(
#    2591         x, bins=bins, range=range, density=density, weights=weights,
#    2592         cumulative=cumulative, bottom=bottom, histtype=histtype,
#    2593         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2594         color=color, label=label, stacked=stacked,
#    2595         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6560, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6558 if orientation == "vertical":
#    6559     convert_units = self.convert_xunits
# -> 6560     x = [*self._process_unit_info([("x", x[0])], kwargs),
#    6561          *map(convert_units, x[1:])]
#    6562 else:  # horizontal
#    6563     convert_units = self.convert_yunits
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py:2521, in _AxesBase._process_unit_info(self, datasets, kwargs, convert)
#    2519     # Update from data if axis is already set but no unit is set yet.
#    2520     if axis is not None and data is not None and not axis.have_units():
# -> 2521         axis.update_units(data)
#    2522 for axis_name, axis in axis_map.items():
#    2523     # Return if no axis is set.
#    2524     if axis is None:
#
# File ~\anaconda3\lib\site-packages\matplotlib\axis.py:1449, in Axis.update_units(self, data)
#    1447 neednew = self.converter != converter
#    1448 self.converter = converter
# -> 1449 default = self.converter.default_units(data, self)
#    1450 if default is not None and self.units is None:
#    1451     self.set_units(default)
#
# File ~\anaconda3\lib\site-packages\matplotlib\category.py:116, in StrCategoryConverter.default_units(data, axis)
#     114 # the conversion call stack is default_units -> axis_info -> convert
#     115 if axis.units is None:
# --> 116     axis.set_units(UnitData(data))
#     117 else:
#     118     axis.units.update(data)
#
# File ~\anaconda3\lib\site-packages\matplotlib\category.py:192, in UnitData.__init__(self, data)
#     190 self._counter = itertools.count()
#     191 if data is not None:
# --> 192     self.update(data)
#
# File ~\anaconda3\lib\site-packages\matplotlib\category.py:227, in UnitData.update(self, data)
#     224 convertible = True
#     225 for val in OrderedDict.fromkeys(data):
#     226     # OrderedDict just iterates over unique values in data.
# --> 227     _api.check_isinstance((str, bytes), value=val)
#     228     if convertible:
#     229         # this will only be called so long as convertible is True.
#     230         convertible = self._str_is_convertible(val)
#
# File ~\anaconda3\lib\site-packages\matplotlib\_api\__init__.py:93, in check_isinstance(_types, **kwargs)
#      91     names.remove("None")
#      92     names.append("None")
# ---> 93 raise TypeError(
#      94     "{!r} must be an instance of {}, not a {}".format(
#      95         k,
#      96         ", ".join(names[:-1]) + " or " + names[-1]
#      97         if len(names) > 1 else names[0],
#      98         type_name(type(v))))
#
# TypeError: 'value' must be an instance of str or bytes, not a float

# %%
dfAutos.head(6)
# Out:
#    symboling  normalized    make fuel aspiration doors        style wheels  \
# 0          2         134  toyota  gas        std   two      hardtop    rwd
# 1          2         134  toyota  gas        std   two    hatchback    rwd
# 2          2         134  toyota  gas        std   two      hardtop    rwd
# 3          2         134  toyota  gas        std   two    hatchback    rwd
# 4          2         134  toyota  gas        std   two  convertible    rwd
# 5         -1          65  toyota  gas        std  four        sedan    fwd
#
#   engine   base  ...  stroke  compression  horsepower    peak City Higway  \
# 0  front   98.4  ...    3.50          9.3       116.0  4800.0   24     30
# 1  front   98.4  ...    3.50          9.3       116.0  4800.0   24     30
# 2  front   98.4  ...    3.50          9.3       116.0  4800.0   24     30
# 3  front   98.4  ...    3.50          9.3       116.0  4800.0   24     30
# 4  front   98.4  ...    3.50          9.3       116.0  4800.0   24     30
# 5  front  102.4  ...    3.54          8.7        92.0  4200.0   29     34
#
#      price City L/100km  Higway L/100km  horsepowerBins
# 0   9639.0     9.791667        7.833333            bajo
# 1   9989.0     9.791667        7.833333            bajo
# 2  11199.0     9.791667        7.833333            bajo
# 3  11549.0     9.791667        7.833333            bajo
# 4  17669.0     9.791667        7.833333            bajo
# 5   8948.0     8.103448        6.911765            bajo
#
# [6 rows x 29 columns]

# %% [markdown]
# <h2 style="color: #99ccff">4. Visualización de Datos</h2>

# %% [markdown]
# <p>En este apartado se van a crear diferentes visualizaciones (Gráficas), las cuales nos ayudan a realizar la interpretaion y analisis de la informacion del set</p>
# </br>
#
# <p>Estos son tres elementos fundamentales para poder crear las visualizaciones:</p>
# <ol>
#     <li>Preguntas de negocio a responder</li>
#     <li>Pleno conocimiento del set de datos</li>
#     <li>Experiencia de negocio</li>
# </ol>

# %%
#Se agrupan los datos por categoria
gf1 = dfAutos.groupby(['horsepowerBins']).count()
# se extrae el indice y la primera colmuna con datos
gf1 = gf1.iloc[:,:1]
gf1
# Out:
#                 symboling
# horsepowerBins
# bajo                  172
# medio                  43
# alto                    5

# %%
#Este codigo permite cambiar el orden de los datos (ascendente / descendente)
tempGFB01 = gf1.sort_values('symboling',ascending=True)
tempGFB01
# Out:
#                 symboling
# horsepowerBins
# alto                    5
# medio                  43
# bajo                  172

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()

eje_x = gf1.index.tolist()
eje_y = gf1['symboling'].tolist()
bar_labels = ['Bajo', 'Medio', 'Alto']
bar_colors = ['#e2e2e2', '#e2e2e2', '#ff4e49']

ax.bar(eje_x, eje_y,label=bar_labels, color=bar_colors) #label=bar_labels,

ax.set_ylabel('Cantida HP')
ax.set_title('Autos agrupados segun HP')
#ax.legend(title='HP color')

plt.show()

# %%
#Se agrupan los datos por categoria
gf2 = dfAutos.groupby(['make']).count()
# se extrae el indice y la primera colmuna con datos
gf2 = gf2.iloc[:,:1]
gf2
# Out:
#                symboling
# make
# alfa-romero            3
# audi                   6
# bmw                    8
# chevrolet              3
# dodge                  9
# honda                 13
# isuzu                  2
# jaguar                 3
# mazda                 17
# mercedes-benz          8
# mercury                1
# mitsubishi            13
# nissan                18
# peugot                11
# plymouth               7
# porsche                4
# renault                2
# saab                   6
# subaru                12
# toyota                46
# volkswagen            24
# volvo                  6

# %%
fig, ax = plt.subplots()

eje_x = gf2.index.tolist()
eje_y = gf2['symboling'].tolist()
y_pos = np.arange(len(eje_x))
bar_colors = ['#e2e2e2', '#e2e2e2', '#e2e2e2', '#e2e2e2','#e2e2e2', '#e2e2e2',
              '#e2e2e2', '#e2e2e2','#e2e2e2', '#e2e2e2','#e2e2e2', '#e2e2e2',
              '#e2e2e2', '#e2e2e2','#e2e2e2', '#e2e2e2','#e2e2e2', '#e2e2e2',
              '#e2e2e2','#ff4e49', '#e2e2e2', '#e2e2e2']

ax.barh(y_pos, eje_y, align='center', color = bar_colors)
ax.set_yticks(y_pos, labels=eje_x)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Cantidad')
ax.set_title('Autos segun Marca')

plt.show()

# %%
dfAutos.head(2)
# Out:
#    symboling  normalized    make fuel aspiration doors      style wheels  \
# 0          2         134  toyota  gas        std   two    hardtop    rwd
# 1          2         134  toyota  gas        std   two  hatchback    rwd
#
#   engine  base  ...  stroke  compression  horsepower    peak City Higway  \
# 0  front  98.4  ...     3.5          9.3       116.0  4800.0   24     30
# 1  front  98.4  ...     3.5          9.3       116.0  4800.0   24     30
#
#     price City L/100km  Higway L/100km  horsepowerBins
# 0  9639.0     9.791667        7.833333            bajo
# 1  9989.0     9.791667        7.833333            bajo
#
# [2 rows x 29 columns]

# %%
dfTemp = dfAutos[['fuel', 'style', 'price']]

# %%
dfTemp
# Out:
#        fuel        style    price
# 0       gas      hardtop   9639.0
# 1       gas    hatchback   9989.0
# 2       gas      hardtop  11199.0
# 3       gas    hatchback  11549.0
# 4       gas  convertible  17669.0
# ..      ...          ...      ...
# 217  diesel        sedan  13845.0
# 218     gas        wagon  12290.0
# 219     gas        sedan  12940.0
# 220     gas        wagon  13415.0
# 221     gas        sedan  15985.0
#
# [222 rows x 3 columns]

# %%
dfAutos
# Out:
#      symboling  normalized        make    fuel aspiration doors        style  \
# 0            2         134      toyota     gas        std   two      hardtop
# 1            2         134      toyota     gas        std   two    hatchback
# 2            2         134      toyota     gas        std   two      hardtop
# 3            2         134      toyota     gas        std   two    hatchback
# 4            2         134      toyota     gas        std   two  convertible
# ..         ...         ...         ...     ...        ...   ...          ...
# 217          0         122  volkswagen  diesel      turbo  four        sedan
# 218          0         122  volkswagen     gas        std  four        wagon
# 219         -2         103       volvo     gas        std  four        sedan
# 220         -1          74       volvo     gas        std  four        wagon
# 221         -2         103       volvo     gas        std  four        sedan
#
#     wheels engine   base  ...  stroke  compression  horsepower    peak City  \
# 0      rwd  front   98.4  ...    3.50          9.3       116.0  4800.0   24
# 1      rwd  front   98.4  ...    3.50          9.3       116.0  4800.0   24
# 2      rwd  front   98.4  ...    3.50          9.3       116.0  4800.0   24
# 3      rwd  front   98.4  ...    3.50          9.3       116.0  4800.0   24
# 4      rwd  front   98.4  ...    3.50          9.3       116.0  4800.0   24
# ..     ...    ...    ...  ...     ...          ...         ...     ...  ...
# 217    fwd  front  100.4  ...    3.40         23.0        68.0  4500.0   33
# 218    fwd  front  100.4  ...    3.40          9.0        88.0  5500.0   25
# 219    rwd  front  104.3  ...    3.15          9.5       114.0  5400.0   23
# 220    rwd  front  104.3  ...    3.15          9.5       114.0  5400.0   23
# 221    rwd  front  104.3  ...    3.15          9.5       114.0  5400.0   24
#
#     Higway    price City L/100km  Higway L/100km  horsepowerBins
# 0       30   9639.0     9.791667        7.833333            bajo
# 1       30   9989.0     9.791667        7.833333            bajo
# 2       30  11199.0     9.791667        7.833333            bajo
# 3       30  11549.0     9.791667        7.833333            bajo
# 4       30  17669.0     9.791667        7.833333            bajo
# ..     ...      ...          ...             ...             ...
# 217     38  13845.0     7.121212        6.184211            bajo
# 218     31  12290.0     9.400000        7.580645            bajo
# 219     28  12940.0    10.217391        8.392857            bajo
# 220     28  13415.0    10.217391        8.392857            bajo
# 221     28  15985.0     9.791667        8.392857            bajo
#
# [222 rows x 29 columns]

# %%
avg_plazo = gf1["symboling"].astype("float").mean(axis=0)
print ("Promedio: ", avg_plazo)
# Out:
# Promedio:  73.33333333333333
